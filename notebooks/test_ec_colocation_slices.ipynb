# %%
import pathlib
import xarray as xr

# %%
ec_overpass_path = pathlib.Path("/work/scratch-nopw2/wkjones/ec_overpasses/")

# %%
ec_overpass_files = sorted(list(ec_overpass_path.glob("*ccld*.nc")))

# %%
len(ec_overpass_files)
# Out:
# 1200

# %%
xr.open_dataset(ec_overpass_files[0]).water_content.T[::-1].plot()
